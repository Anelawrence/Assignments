# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

sales = pd.read_csv('company_sales_data.csv')
sales.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#Compare any two products sales data using a bar chart.
x = np.arange(len(sales['month_number']))
month = ['Jan', 'Feb', 'Mar', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

y1 = sales['toothpaste']
plt.bar(x -0.2,y1, width=0.4, label = 'toothpaste')

y2 = sales['facewash']
plt.bar(x +0.2,y2, width=0.4, label = 'facewash')

plt.title('MONTHLY SALES')
plt.xticks(x, month)
plt.xlabel('Months')
plt.ylabel('Sales(#)')
plt.legend()
plt.show()

plt.savefig("bar_plot.png")

# %%
#Assuming the average monthly sales of bathing soap is 10k, 
#visualize the sales data of bathing soap of all months, showing how they differ from the average sale.

x = np.arange(len(sales['month_number']))
month = ['Jan', 'Feb', 'Mar', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
yerr = np.array(list(map(lambda x: 10000-x, sales['bathingsoap'])))
yerr = np.absolute(yerr)

y1 = sales['bathingsoap']
plt.bar(x,y1, yerr=yerr, capsize=10)

plt.title('MONTHLY SALES OF BATHING SOAP')
plt.xticks(x, month)
plt.xlabel('Months')
plt.ylabel('Sales(#)')
plt.legend()
plt.show()

plt.savefig("error_bar.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Calculate the total sales data for the year of  each product and represent it on a pie chart

# Getting a list of the products' total
products = sales.drop(['month_number', 'total_units', 'total_profit'], axis=1) #Removing the unwanted columns
products.loc['total'] = products.sum()  #summing up each column of the new df on index 'total'
totals = list(products.loc['total'])    #list of the totals
items = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']

plt.pie(totals, labels=items, autopct='%0.1f%%')
plt.axis('equal')
plt.title('SALES OF PRODUCTS IN THE YEAR 2021')
plt.plot()

plt.savefig("pie_chart.png")
